# %% [markdown]
# # Análise exploratoria dos dados

# %% [markdown]
# #### Iniciando com importação dos pacotes necessários

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Fazendo a leitura dos bancos de dados

# %%
dados_treino = ".\desafio_manutencao_preditiva_treino.csv"
db = pd.read_csv(dados_treino)

# %% [markdown]
# #### Analise inicial dos dados

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6667 entries, 0 to 6666
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   udi                    6667 non-null   int64
#  1   product_id             6667 non-null   object
#  2   type                   6667 non-null   object
#  3   air_temperature_k      6667 non-null   float64
#  4   process_temperature_k  6667 non-null   float64
#  5   rotational_speed_rpm   6667 non-null   int64
#  6   torque_nm              6667 non-null   float64
#  7   tool_wear_min          6667 non-null   int64
#  8   failure_type           6667 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 468.9+ KB

# %%
db.describe()
# Out:
#                 udi  air_temperature_k  process_temperature_k  \
# count   6667.000000        6667.000000            6667.000000
# mean    4994.589921         299.992515             309.992620
# std     2896.125718           1.994710               1.488101
# min        1.000000         295.300000             305.700000
# 25%     2496.500000         298.300000             308.800000
# 50%     4983.000000         300.000000             310.000000
# 75%     7510.500000         301.500000             311.100000
# max    10000.000000         304.500000             313.800000
#
#        rotational_speed_rpm    torque_nm  tool_wear_min
# count           6667.000000  6667.000000    6667.000000
# mean            1537.419529    40.058512     108.098095
# std              177.182908     9.950804      63.359915
# min             1168.000000     3.800000       0.000000
# 25%             1422.500000    33.200000      54.000000
# 50%             1503.000000    40.200000     108.000000
# ...

# %% [markdown]
# Como temos 5 variáveis quantitativas, olhar para sua distribuição e métricas como média e mediana nos dá noção de como se comportam esses dados.

# %%
db.failure_type.value_counts()
# Out:
# No Failure                  6435
# Heat Dissipation Failure      75
# Power Failure                 63
# Overstrain Failure            52
# Tool Wear Failure             30
# Random Failures               12
# Name: failure_type, dtype: int64

# %% [markdown]
# Podemos observar que os dados estão muito assimétricos em relação a variavel que desejamos prever.
#
# Existem muitas maquinas que não apresentam falha (No Failure) ao compararmos com qualquer outro tipo de falha. Neste caso

# %% [markdown]
# Escolhendo as variáveis que usaremos no modelo e desenhando alguns gráficos

# %%
feats = ['type', 'air_temperature_k','process_temperature_k', 'rotational_speed_rpm', 'torque_nm','tool_wear_min']

# %%
sns.set_theme(style='whitegrid')

for feat in feats:
    sns.displot(db,x=feat)

# %%
# Out:
# True
